# %%
pip install fastapi uvicorn
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install nest_asyncio

# %%
# !pip install nest_asyncio uvicorn

# %%
import nest_asyncio
from fastapi import FastAPI
import uvicorn

nest_asyncio.apply()

# %%
app = FastAPI()

@app.get("/employers")
def get_employers(q: str):
    # Importa los módulos necesarios
    from fastapi import FastAPI
    import requests
    
    # Crea una instancia de la aplicación FastAPI
    app = FastAPI()
    
    # Define una ruta para la acción employers
    @app.get("/employers")
    def get_employers(q: str):
        # Construye la URL de la API de Glassdoor con los parámetros
        base_url = "http://api.glassdoor.com/api/api.htm"
        params = {
            "v": 1,
            "format": "json",
            "t.p": "yourID",
            "t.k": "yourkey",
            "userip": "8.28.178.133",
            "useragent": "Mozilla",
            "action": "employers",
            "q": "Data Science"
        }
        # Hace una petición GET a la API de Glassdoor
        response = requests.get(base_url, params=params)
        # Devuelve la respuesta en formato JSON
        return response.json()

# %%
uvicorn.run(app, host="0.0.0.0", port=8000)
# Out:
# INFO:     Started server process [14912]
# INFO:     Waiting for application startup.
# INFO:     Application startup complete.
# INFO:     Uvicorn running on http://0.0.0.0:8000 (Press CTRL+C to quit)
# INFO:     Shutting down
# INFO:     Waiting for application shutdown.
# INFO:     Application shutdown complete.
# INFO:     Finished server process [14912]

# %%
import requests

# Define la URL y los parámetros
url = 'https://serpapi.com/search'
params = {
    'engine': 'google_jobs',
    'q': 'cientifico de datos',  # Reemplaza esto con el título del trabajo que estás buscando
    'location': 'Spain',  # Reemplaza esto con la ubicación que estás buscando
    'api_key': '6212cfc0a2334dc7ff7fe69887340584a1bb21f2d7f5f36d9ef8cd533e222ccf'  # Reemplaza esto con tu clave de API de SerpApi
}

# Haz una solicitud GET a la API
response = requests.get(url, params=params)

# Imprime la respuesta en formato JSON
print(response.json())
# Out:
# {'search_metadata': {'id': '650a400c7d171a01b3aa2e97', 'status': 'Success', 'json_endpoint': 'https://serpapi.com/searches/b186bdd601a5c46f/650a400c7d171a01b3aa2e97.json', 'created_at': '2023-09-20 00:42:52 UTC', 'processed_at': '2023-09-20 00:42:52 UTC', 'google_jobs_url': 'https://www.google.com/search?q=cientifico+de+datos&ibp=htl;jobs&uule=w+CAIQICIFU3BhaW4', 'raw_html_file': 'https://serpapi.com/searches/b186bdd601a5c46f/650a400c7d171a01b3aa2e97.html', 'total_time_taken': 7.27}, 'search_parameters': {'q': 'cientifico de datos', 'engine': 'google_jobs', 'location_requested': 'Spain', 'location_used': 'Spain', 'google_domain': 'google.com'}, 'jobs_results': [{'title': 'Científico de Datos', 'company_name': 'SDG Group', 'location': ' Anywhere ', 'via': 'via SDG Group Careers', 'description': '¡Hola Data Lover! 💙\n\nEn SDG, no solo tendrás la oportunidad de formar parte de algo increíble, ¡sino que vivirás lo que significa ser un auténtico especialista en Data & Analytics!\n\n¿Estás
# ...

# %%
import pandas as pd

# Extrae la información relevante de los resultados de la búsqueda
jobs_data = []
for job in response.json()['jobs_results']:
    job_info = {
        'title': job.get('title'),
        'company_name': job.get('company_name'),
        'location': job.get('location'),
        'description': job.get('description'),
        # Asegúrate de que el campo 'salaries' exista antes de intentar acceder a él
        'salaries': job.get('salaries') if 'salaries' in job else None,
    }
    jobs_data.append(job_info)

# Crea un DataFrame con los datos
df = pd.DataFrame(jobs_data)

# Guarda el DataFrame como un archivo CSV
df.to_csv('jobs_data.csv', index=False)

# %%
import re

# %%
for i in range(len(df)): 
    list(re.search("€",df.description[i]).span())[0]
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[36], line 2
#       1 for i in range(len(df)):
# ----> 2     list(re.search("€",df.description[i]).span())[0]
#
# AttributeError: 'NoneType' object has no attribute 'span'

# %%
print(df.description[2][830:838])
# Out:
#  40.000€

# %%
import requests

# Define la URL y los parámetros
url = 'https://serpapi.com/search'
params = {
    'engine': 'google_jobs',
    'q': 'dentist',  # Reemplaza esto con el título del trabajo que estás buscando
    'location': 'United States',  # Reemplaza esto con la ubicación que estás buscando
    'api_key': '6212cfc0a2334dc7ff7fe69887340584a1bb21f2d7f5f36d9ef8cd533e222ccf'  # Reemplaza esto con tu clave de API de SerpApi
}

# Haz una solicitud GET a la API
response = requests.get(url, params=params)

# Imprime la respuesta en formato JSON
print(response.json())
# Out:
# {'search_metadata': {'id': '650a3fa15b54ef3b01ca824a', 'status': 'Success', 'json_endpoint': 'https://serpapi.com/searches/50837cadfadb4180/650a3fa15b54ef3b01ca824a.json', 'created_at': '2023-09-20 00:41:05 UTC', 'processed_at': '2023-09-20 00:41:05 UTC', 'google_jobs_url': 'https://www.google.com/search?q=dentist&ibp=htl;jobs&uule=w+CAIQICINVW5pdGVkIFN0YXRlcw', 'raw_html_file': 'https://serpapi.com/searches/50837cadfadb4180/650a3fa15b54ef3b01ca824a.html', 'total_time_taken': 2.31}, 'search_parameters': {'q': 'dentist', 'engine': 'google_jobs', 'location_requested': 'United States', 'location_used': 'United States', 'google_domain': 'google.com'}, 'jobs_results': [{'title': 'Dentist', 'company_name': 'Barton Associates Inc.', 'location': '  United States   ', 'via': 'via LinkedIn', 'description': 'Looking for your next locum tenens opportunity? Look no further! Our client in Arizona is looking for a dentist to begin coverage immediately. Hours include 7:30a – 5:30p and other similar 
# ...

# %%
import pandas as pd

# Extrae la información relevante de los resultados de la búsqueda
jobs_data = []
for job in response.json()['jobs_results']:
    job_info = {
        'title': job.get('title'),
        'company_name': job.get('company_name'),
        'location': job.get('location'),
        'description': job.get('description'),
        # Asegúrate de que el campo 'salaries' exista antes de intentar acceder a él
        'salaries': job.get('salaries') if 'salaries' in job else None,
    }
    jobs_data.append(job_info)

# Crea un DataFrame con los datos
df = pd.DataFrame(jobs_data)

# Guarda el DataFrame como un archivo CSV
df.to_csv('jobs_data.csv', index=False)

# %%
df
# Out:
#                                                title  \
# 0                                            Dentist
# 1                                    General Dentist
# 2                                            Dentist
# 3                                    General Dentist
# 4                                  Full-Time Dentist
# 5                                  Full-Time Dentist
# 6                                    General Dentist
# 7                                            Dentist
# 8                Associate Dentist - Rock Spring, WY
# 9  Associate Dentist Sought in Lancaster! Up to $...
#
#                    company_name            location  \
# 0        Barton Associates Inc.    United States
# 1  Confidential Dental Practice    United States
# 2                  Aspen Dental       Owasso, OK
# 3             The Dentist Agent    United States
# 4              Nyulangonedental    United States
# 5     Signature Dental Partners    United States
# ...
